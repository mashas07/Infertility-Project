# %%
class Photon:
    """A photon with wavelength-based properties."""

    c = 299792458  # Speed of light (m/s)
    h = 6.626e-34  # Planck's constant (J⋅s)

    def __init__(self, wavelength):  # ← ADD THIS!
        self.__wavelength = wavelength


    @property
    def wavelength(self):
        return self.__wavelength

    @wavelength.setter
    def set_wavelength(self, wavelength):
        if wavelength > 0:
            self.__wavelength = wavelength

    ''''@property
    def get_wavelength(self):
        return self.__wavelength'''

    @property
    def frequency(self):
        return self.c/self.__wavelength

    @property
    def energy(self):
        return self.h * self.frequency


    # Your code here
    pass

# Test with visible light (500 nm)
photon = Photon(500e-9)
print(f"Wavelength: {photon.wavelength*1e9:.0f} nm")
print(f"Frequency: {photon.frequency:.2e} Hz")
print(f"Energy: {photon.energy:.2e} J")
# Expected: 500 nm, ~6e14 Hz, ~4e-19 J
# Out:
# Wavelength: 500 nm
# Frequency: 6.00e+14 Hz
# Energy: 3.97e-19 J

# %%
def print_n(num):
    v = list(num)
    print(sum(v))
num = input()
#print_n(num)
print(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       4 num = input()
#       5 #print_n(num)
# ----> 6 print(v)
#
# NameError: name 'v' is not defined

# %%
class DataLoader:
    '''Downloads, cleans, filters the data '''

    def __init__(self, csv_path=None):
        self.csv_path = csv_path

    def load_data(self, csv_path=None):

        '''Find and download the CSV file, extract data from it
        Args:
            csv_path (str, optional): Path to the CSV file.
        Output:
            dataframe (pandas.DataFrame): Dataframe containing the data
        '''

        if csv_path:
            self.csv_path = csv_path

        else:
            print("Downloading dataset from Kaggle...")
            path = kagglehub.dataset_download("fida5073/female-infertility")
            print(f"Dataset downloaded to: {path}")

            if os.path.isdir(path):
                csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
                self.csv_path = os.path.join(path, csv_files[0])
                print(f"Found CSV file: {csv_files[0]}")

            else:
                self.csv_path = path


            if not self.csv_path:
                raise ValueError("CSV path must be provided")
            if not os.path.exists(self.csv_path):
                raise FileNotFoundError(f"File not found: {self.csv_path}")
            if os.path.isdir(self.csv_path):
                raise IsADirectoryError(f"Path is a directory, not a file: {self.csv_path}")
            print(f"Loading data from {self.csv_path}...")

            self.data = pd.read_csv(self.csv_path)
            print(f"Data loaded successfully. Shape: {self.data.shape}")
            print(f"\nColumns in dataset: {list(self.data.columns)}")

            return self.data


    load_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 class DataLoader:
#       2     '''Downloads, cleans, filters the data '''
#       4     def __init__(self, csv_path=None):
#
# Cell In[19], line 48, in DataLoader()
#      43         print(f"\nColumns in dataset: {list(self.data.columns)}")
#      45         return self.data
# ---> 48 load_data()
#
# TypeError: DataLoader.load_data() missing 1 required positional argument: 'self'
